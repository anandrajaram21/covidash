# %%
import cnn,time

# %%
a = time.time()
pred,MAPE,figure = cnn.cnn_predict("confirmed","Tanzania")
b = time.time()

# %%
b - a
# Out:
# 87.11943316459656

# %%
pred
# Out:
# [509, 509, 509, 509, 509, 509, 509, 509, 509, 509, 509, 510, 510, 511]

# %%
MAPE
# Out:
# 0.02

# %%
figure.show()
