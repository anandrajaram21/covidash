# %%
import cnn,time

# %%
a = time.time()
pred,MAPE,figure = cnn.cnn_predict("deaths","Australia")
b = time.time()

# %%
b - a
# Out:
# 93.87527704238892

# %%
pred
# Out:
# [908, 908, 909, 909, 909, 910, 910, 911, 912, 913, 913, 914, 915, 916]

# %%
MAPE
# Out:
# 0.35

# %%
figure.show()
