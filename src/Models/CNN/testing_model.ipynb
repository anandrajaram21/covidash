# %% [markdown]
# # TESTING THE MODEL
#
# ### Please update stats after running tests

# %%
import cnn

# %%
countries = ["Botswana","Vietnam","Argentina","Zimbabwe"]
sts = ["confirmed","deaths","recovered"]
l = []
count = 11
for C in countries:
    l = []
    for S in sts:
        _,MASE,_ = cnn.cnn_predict(S,C)
        l.append(MASE)
    print(f"{count}.{C} -> {l}")
    count += 1

# %%
pred,MASE,fig = cnn.cnn_predict("recovered","Botswana")

# %%
fig.show()
