# %% [markdown]
# # TESTING THE MODEL
#
# ### Please update stats after running tests

# %%
import cnn

# %%
pred,MASE,figure = cnn.cnn_predict("deaths","US")
print(MASE)
# Out:
# 0.53

# %%
pred
# Out:
# [5462171,
#  5516595,
#  5578770,
#  5673923,
#  5743083,
#  5832127,
#  5904745,
#  5982705,
#  6059729,
#  6127259,
#  6214852,
#  6298699,
#  6393827,
#  6474989]

# %%
figure.show()
