# %%
import cnn,time

# %%
a = time.time()
pred,MAPE,figure = cnn.cnn_predict("confirmed","India")
b = time.time()

# %%
b - a
# Out:
# 86.73890781402588

# %%
pred
# Out:
# [9575531,
#  9613790,
#  9652199,
#  9688202,
#  9722384,
#  9757803,
#  9795229,
#  9832579,
#  9870112,
#  9909037,
#  9943484,
#  9979037,
#  10013765,
#  10048940]

# %%
MAPE
# Out:
# 0.66

# %%
figure.show()
